# %% [markdown]
# # Part II - 2019 fordgobike trip data Exploration
# ## by: Umar Muhammad Aminu

# %% [markdown]
# ## Investigation Overview
# > In this presentation, I plan to communicate the key insights that i derived from my exploration. The key insights are: Females bike riders appear to favour long trips(over 800secs), more bike trips happen during the evening period and the majority of the bikers are males
#
# ## Dataset Overview
#
# > The data set includes information about individual rides made in a bike-sharing system covering the greater San Francisco Bay area. it includes information such as trip duration, start station, user gender etc. Overall, the dataset contains 16 features(columns) describing 183412 bike trips (rows)

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
bike_data = pd.read_csv('201902-fordgobike-tripdata_with_city.csv')

# %% [markdown]
# ## (Visualization 1)
#
# > It can be seen from the plot that over 70 percent of the people that uses the bikea belong to male gender

# %%
x, labels = bike_data.member_gender.value_counts().values, bike_data.member_gender.value_counts().index
plt.pie(x, labels=labels, startangle=90, wedgeprops = {'width' : 0.4});
plt.title('Percentage of bikers per gender');

# %% [markdown]
# ## (Visualization 2)
#
# > It can be seen that Females appear to take long trips more. For males, Very short trip is the most popular while thier is no much difference in trip duration for people of the other gender

# %%
sb.countplot(x='trip_duration_group', data=bike_data, hue='member_gender');
plt.title('Trip duration group count per gender');

# %% [markdown]
# ## (Visualization 3)
# >It can be seen from the above plot that Evening period is the most populous period for bike trips followed by Morning and then Noon period

# %%
sb.countplot(data=bike_data, x='period', color=sb.color_palette()[1]);
plt.title('Number of trips per period');

# %%
# !jupyter nbconvert Part_II_slide_deck_template.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Part_II_slide_deck_template.ipynb to slides
# [NbConvertApp] Writing 622878 bytes to Part_II_slide_deck_template.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Serving your slides at http://127.0.0.1:8000/Part_II_slide_deck_template.slides.html
# Use Control-C to stop this server
# WARNING:tornado.access:404 GET /favicon.ico (127.0.0.1) 0.76ms
